# %%
import matplotlib.pyplot as plt
x=[171,151,124,134,150]
y=[80,60,45,50,60]
plt.plot(x,y,'y')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()
for i in x():
  if i>=120:
    plt.plot(x[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b6668a397ce8> in <cell line: 9>()
#       7 plt.show()
#       8 l=[]
# ----> 9 for i in x():
#      10   if i>=120:
#      11     l.append[i]
#
# TypeError: 'list' object is not callable
